# %% [markdown]
# <a href="https://colab.research.google.com/github/prithwis/Centaur/blob/main/Alpha_Centaur_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/images/CentaurBanner2.png)<br>
#
#
# <hr>
#
# [Prithwis Mukerjee](http://www.linkedin.com/in/prithwis)<br>

# %% [markdown]
# #Centaur - Alpha
# The Centaur Project is a disciplined strategy sandbox where humans, AI, and a roll of the dice take turns shaping a shared world — without anyone being allowed to cheat by predicting the future. See [Centaur](https://github.com/prithwis/Centaur) on Github for more information

# %% [markdown]
# # Strategic Simulation Notebook
#
# This notebook implements a tri-layer geopolitical simulation engine composed of three distinct analytical agents:
#
# ### 1. ZeitWorld
# A neutral state recorder that maintains the evolving **World State** in a faceted, non-interpretive format.
# It updates structural reality strictly based on executed actions, without analysis or judgment.
#
# ### 2. Centaur
# A systemic evaluator that assesses proposed actions in terms of institutional coherence, escalation risk, economic burden, and equilibrium stability.
# Centaur judges strategic soundness within the broader international system.
#
# ### 3. Chanakya
# An agency-specific strategic engine that models adversarial response pathways.
# For a specified **Principal Actor**, it generates two probabilistic strategic reactions grounded in power calculus, leverage dynamics, and incentive alignment.
#
# ---
#
# Together, these components form the first operational version of the **Centaur Project** — a structured framework for simulating strategic interaction, adversarial dynamics, and disciplined world-state evolution without narrative drift or normative bias.

# %% [markdown]
# #Install PreRequisites and Utilities

# %% [markdown]
# Load API key<br>
# OPENAI_API_KEY needs to defined as a Colab "secret" for the Google ID used to run this notebook

# %%
# !pip install --quiet openai

# !wget -q -O Centaur.py https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/utilities/Centaur_v2.py
import Centaur as cn
# Out:
# API key loaded ✔
# Logged in as Calcutta prithwis@yantrajaal.com

# %% [markdown]
# Select Model

# %%
# ---------------------------------------------------------------------------------------------------------
#| Model            | Best For                  | Notes                                       |
#| ---------------- | ------------------------- | ------------------------------------------- |
#| **GPT-4.1**      | Highest-quality reasoning | Ideal judge for complex scenario evaluation |
#| **GPT-4.1-mini** | Balanced reasoning & cost | Strong choice for adjudication logic        |
#| **GPT-4.1-nano** | High volume, low cost     | Good for simple reasoning tasks             |
#| **gpt-4o-mini**  | Prototyping & cheap       | Great starter, but upgrade recommended      |
# ---------------------------------------------------------------------------------------------------------
cModel = "gpt-4o-mini"
#cModel = "gpt-4.1-mini"

# %% [markdown]
# #Define ZeitWorld

# %%
# !wget -q -O ZWRole.txt https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/ZeitWorldRole_v4.txt

with open("/content/ZWRole.txt", "r", encoding="utf-8") as f:
    ZW_Role = f.read()
# Optional sanity check
print(ZW_Role[:100])
# Out:
# ROLE NAME: ZEITWORLD
# Version: v4
# Mode: STRICT-LEDGER
#
# IDENTITY
# Zeitworld is the World State Ledger o

# %%
def ZeitWorld(
    world_input: str,
    executed_action: str = None
):
    """
    ZeitWorld — World Synthesizer

    Inputs:
    - world_input:
        Either:
        (a) Raw unstructured narrative describing the world, OR
        (b) A semi-structured faceted world state from a previous turn

    - executed_action:
        A description of an action that has already been executed.
        May be None during world initialization.

    Output:
    - A semi-structured faceted world narrative suitable for subsequent steps.
    """

    ROLE = ZW_Role                  # As read from text file

    context = f"""
    WORLD INPUT:
    {world_input}

    EXECUTED ACTION:
    {executed_action if executed_action else "None (world initialization phase)"}

    Task:
    1. If this is initialization:
    - Extract salient facets from the world input.
    - Name each facet succinctly.
    - Stabilize an initial interpretive world state.

    2. If this is an update:
    - Reflect only the direct and second-order consequences
        of the executed action.
    - Update relevant facets conservatively.
    - Leave unrelated facets unchanged.

    Return the updated world as a faceted narrative state.
    """

    llm_response = cn.OpenAI_llm_call(
        ROLE,
        context,
        model=cModel
    )

    llm_response["header"] = "ZeitWorld | " + llm_response["header"]

    return llm_response

# %% [markdown]
# #Initialise World

# %%
#!cat World_0.txt
#!wget -q -O World_0.txt https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/worlds/REEWorld_Simple.txt
# !wget -q -O World_0.txt https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/worlds/REEWorld_01.txt

with open("/content/World_0.txt", "r", encoding="utf-8") as f:
    World_0 = f.read()
# Optional sanity check
#print(World_0[:500])

#centaur.reveal(KalDarpanWorldUpdate(World_0))
World_1 = cn.echo(ZeitWorld(World_0))
# Out:
# Response from  ZeitWorld | OpenAI gpt-4o-mini  | token usage 934 + 2060 = 2994
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] The global landscape of Rare Earth Elements (REEs) represents
# a critical intersection of advanced materials science, industrial strategy, and geopolitical
# competition. Often termed the "vitamins of modern industry," these 17 elements—including the
# lanthanide series plus scandium and yttrium—are indispensable due to their unique magnetic,
# luminescent, and conductive properties. While relatively abundant in the Earth's crust, they are
# rarely found in minable concentrations, and the technical complexity of their refinement has created
# a highly concentrated global market.
#
# [Facet: Technological Foundations and Applications] The primary driver of the REE market is the
# production of permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These are the
# strongest permanent magnets commercially available, providing a high strength-to-weight ratio
# essential for high-performance motors. REEs are the backbone of clean energy technologies.
# Neodymium, praseodymium, dysprosium, and terbium are critical for electric vehicle (EV) motors and
# wind turbine generators. The International Energy Agency (IEA) projects that demand for these
# minerals could increase three to seven times by 2040 to meet global climate goals. Military
# dependency is a major strategic concern. A single F-35 stealth fighter requires approximately 900
# lbs of rare earth materials for its radar, electronic warfare systems, and motors, while a Virginia-
# class submarine utilizes roughly 9,200 lbs. Beyond magnetism, REEs are vital for high-end optical
# glass. For example, Canon utilizes fluorite (calcium fluoride) and Ultra Low Dispersion (UD) lenses
# to correct chromatic aberration, enabling high-resolution imaging in products ranging from consumer
# cameras to the 8.2-meter Subaru telescope.
#
# [Facet: Market Concentration and the Chinese Hegemony] Currently, the REE supply chain is defined by
# a deep-seated Chinese monopoly. China controls approximately 60% of global mining, 90% of refining
# and processing, and 85% of finished magnet manufacturing. This dominance was established through
# decades of state support, lower environmental standards, and competitive pricing that undercut
# international producers. In 2025, China introduced two waves of export controls on REEs, metals, and
# magnet-making technologies, citing national security interests. These measures included a first-of-
# its-kind extraterritorial reach, requiring foreign firms to obtain approval for products containing
# even 0.1% Chinese-sourced REEs.
#
# [Facet: The Global Pursuit of Diversification] The vulnerability of a single-source supply chain has
# spurred major economies to invest in "mine-to-magnet" resilience. Following a 2010 de facto Chinese
# embargo, Japan implemented a multi-decade strategy to diversify its supply. Through the state-backed
# JOGMEC and trading houses like Sojitz, Japan invested in Lynas Rare Earths, an Australian miner with
# a major refinery in Malaysia. This allowed Japan to reduce its reliance on Chinese REEs from 90% to
# roughly 60% by 2024. After a collapse in production in the late 1990s, the Mountain Pass mine in
# California has resumed operations, producing 45,000 tons of REO in 2024. The U.S. government is also
# funding domestic magnet facilities to bridge the gap between raw ore and finished components. IREL
# (India) Limited, under the Department of Atomic Energy, is scaling its operations to tap into
# India's significant reserves, aiming to boost mining capacity by 400% over the next decade. Future
# supply may be reshaped by massive undeveloped reserves in Greenland (1.5 million tons) and Brazil
# (21 million tons), though these projects face significant infrastructure and environmental hurdles.
#
# [Facet: The Environmental and Future Outlook] The REE industry faces an ESG paradox: the "green"
# technologies it enables require a highly toxic refining process. The extraction of elements like
# cerium and neodymium involves dissolving minerals in sulphuric and nitric acid, resulting in
# radioactive chemical waste. In Baotou, Inner Mongolia, this has created a city-sized "toxic lake" of
# black sludge that stands as a stark reminder of the industry's environmental cost. To mitigate these
# impacts and supplement primary supply, the IEA suggests that scaling up recycling could reduce the
# need for new mines by 25% to 40% by mid-century. Currently, however, recycling rates for REEs remain
# below 10%. As technology continues to evolve, the challenge remains for the global market to balance
# the exploding demand for "clean" tech minerals with the geopolitical and environmental costs of
# their production.

# %% [markdown]
# #Update World State after Initial ("Trigger") Action
# State of World moves from World_1 to World_2

# %%
Action1 = """
China blocks the export of neodymium magnets to India.
"""

Action2 = """
China has applied a new policy. This is the 0.1% rule (often referred to as a de minimis rule) is an October 2025
export control regulation requiring licenses for exporting foreign-manufactured
items that contain 0.1% or more (by value) of specific Chinese-sourced rare earth
elements or materials. This policy applies to rare earth permanent magnets, targets,
and intermediate products, targeting high-tech and defense industries.
"""

TriggerAction = Action1 + "  "+  Action2

World_2 = cn.echo(ZeitWorld(World_1, TriggerAction))
# Out:
# Response from  ZeitWorld | OpenAI gpt-4o-mini  | token usage 946 + 2137 = 3083
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] The global landscape of Rare Earth Elements (REEs) represents
# a critical intersection of advanced materials science, industrial strategy, and geopolitical
# competition. Often termed the "vitamins of modern industry," these 17 elements—including the
# lanthanide series plus scandium and yttrium—are indispensable due to their unique magnetic,
# luminescent, and conductive properties. While relatively abundant in the Earth's crust, they are
# rarely found in minable concentrations, and the technical complexity of their refinement has created
# a highly concentrated global market.
#
# [Facet: Technological Foundations and Applications] The primary driver of the REE market is the
# production of permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These are the
# strongest permanent magnets commercially available, providing a high strength-to-weight ratio
# essential for high-performance motors. REEs are the backbone of clean energy technologies.
# Neodymium, praseodymium, dysprosium, and terbium are critical for electric vehicle (EV) motors and
# wind turbine generators. The International Energy Agency (IEA) projects that demand for these
# minerals could increase three to seven times by 2040 to meet global climate goals. Military
# dependency is a major strategic concern. A single F-35 stealth fighter requires approximately 900
# lbs of rare earth materials for its radar, electronic warfare systems, and motors, while a Virginia-
# class submarine utilizes roughly 9,200 lbs. Beyond magnetism, REEs are vital for high-end optical
# glass. For example, Canon utilizes fluorite (calcium fluoride) and Ultra Low Dispersion (UD) lenses
# to correct chromatic aberration, enabling high-resolution imaging in products ranging from consumer
# cameras to the 8.2-meter Subaru telescope.
#
# [Facet: Market Concentration and the Chinese Hegemony] Currently, the REE supply chain is defined by
# a deep-seated Chinese monopoly. China controls approximately 60% of global mining, 90% of refining
# and processing, and 85% of finished magnet manufacturing. This dominance was established through
# decades of state support, lower environmental standards, and competitive pricing that undercut
# international producers. In 2025, China introduced two waves of export controls on REEs, metals, and
# magnet-making technologies, citing national security interests. These measures included a first-of-
# its-kind extraterritorial reach, requiring foreign firms to obtain approval for products containing
# even 0.1% Chinese-sourced REEs. China blocks the export of neodymium magnets to India.
#
# [Facet: The Global Pursuit of Diversification] The vulnerability of a single-source supply chain has
# spurred major economies to invest in "mine-to-magnet" resilience. Following a 2010 de facto Chinese
# embargo, Japan implemented a multi-decade strategy to diversify its supply. Through the state-backed
# JOGMEC and trading houses like Sojitz, Japan invested in Lynas Rare Earths, an Australian miner with
# a major refinery in Malaysia. This allowed Japan to reduce its reliance on Chinese REEs from 90% to
# roughly 60% by 2024. After a collapse in production in the late 1990s, the Mountain Pass mine in
# California has resumed operations, producing 45,000 tons of REO in 2024. The U.S. government is also
# funding domestic magnet facilities to bridge the gap between raw ore and finished components. IREL
# (India) Limited, under the Department of Atomic Energy, is scaling its operations to tap into
# India's significant reserves, aiming to boost mining capacity by 400% over the next decade. Future
# supply may be reshaped by massive undeveloped reserves in Greenland (1.5 million tons) and Brazil
# (21 million tons), though these projects face significant infrastructure and environmental hurdles.
#
# [Facet: The Environmental and Future Outlook] The REE industry faces an ESG paradox: the "green"
# technologies it enables require a highly toxic refining process. The extraction of elements like
# cerium and neodymium involves dissolving minerals in sulphuric and nitric acid, resulting in
# radioactive chemical waste. In Baotou, Inner Mongolia, this has created a city-sized "toxic lake" of
# black sludge that stands as a stark reminder of the industry's environmental cost. To mitigate these
# impacts and supplement primary supply, the IEA suggests that scaling up recycling could reduce the
# need for new mines by 25% to 40% by mid-century. Currently, however, recycling rates for REEs remain
# below 10%. As technology continues to evolve, the challenge remains for the global market to balance
# the exploding demand for "clean" tech minerals with the geopolitical and environmental costs of
# their production.

# %% [markdown]
# #Enter the Centaur

# %%
# !wget -q -O CentaurRole.txt https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/CentaurRole_v2.txt
with open("/content/CentaurRole.txt", "r", encoding="utf-8") as f:
    Centaur_Role = f.read()
# Optional sanity check
print(Centaur_Role[:100])
# Out:
# ROLE NAME: Centaur
# Version: v2
# Mode: Adjudicative
#
# IDENTITY
# Centaur is the system-level adjudicator

# %%
def Centaur(
    world_state: str,
    trigger_action: str,
    suggested_response: str
):

    ROLE = Centaur_Role

    # ---------------------------------------------------------------------------------------------------------

    context = f"""
    WORLD STATE:
    {world_state}

    TRIGGER ACTION:
    {trigger_action}

    SUGGESTED HUMAN RESPONSE:
    {suggested_response}

    Provide adjudication according to the stated ROLE.
    """

    llm_response = cn.OpenAI_llm_call(ROLE, context, model=cModel)
    llm_response["header"] = "Centaur w/ " + llm_response["header"]

    return llm_response

# %% [markdown]
# #A, B - Two optional responses from Human

# %% [markdown]
# ##Response A | Centaur Feedback

# %%
HumanResponse_A = """
Explore indirect procurement through international trading houses and
non-transparent spot markets to bridge short-term shortages, while avoiding
formal policy announcements. Accept higher costs and limited volumes as a
temporary measure.

Simultaneously signal willingness to negotiate technical and regulatory
concerns raised by China, without making public concessions.
"""

_ = cn.echo(Centaur(World_2, TriggerAction,HumanResponse_A))
# Out:
# Response from  Centaur w/ OpenAI gpt-4o-mini  | token usage 231 + 1807 = 2038
#
# ----------------------------------------------------------------------------------------------------
# Verdict   The proposed action may provide short-term relief but risks entrenching dependency on
# opaque markets and could undermine long-term strategic positioning.
#
# Explanation
#
# - Strategic Context   The action addresses immediate supply chain disruptions caused by China's
# export restrictions but does not fundamentally alter the underlying dependency on Chinese REEs.
#
# - Signaling and Leverage   Engaging in indirect procurement may signal to China a willingness to
# negotiate, but it could also be perceived as a sign of weakness, potentially diminishing bargaining
# leverage.
#
# - Institutional and Legal   The approach skirts formal policy announcements, which may avoid
# immediate backlash but could raise concerns about compliance with international trade norms and
# transparency.
#
# - Economic and Industrial   Higher costs and limited volumes could strain budgets and operational
# efficiency in the short term, impacting competitiveness in high-tech and defense sectors.
#
# - Escalation and Retaliation   China may respond to perceived attempts to circumvent its controls
# with further restrictions or retaliatory measures, escalating tensions in the bilateral
# relationship.
#
# - Long-Term Equilibrium   While the action may provide temporary relief, it does not contribute to a
# sustainable solution for diversifying supply chains or reducing reliance on Chinese REEs,
# potentially perpetuating vulnerabilities.

# %% [markdown]
# ##Response A | Change of World State
# State of World moves from World_2 to World_3A

# %%
World_3A = cn.echo(ZeitWorld(World_2, HumanResponse_A))
# Out:
# Response from  ZeitWorld | OpenAI gpt-4o-mini  | token usage 1009 + 2102 = 3111
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] The global landscape of Rare Earth Elements (REEs) represents
# a critical intersection of advanced materials science, industrial strategy, and geopolitical
# competition. Often termed the "vitamins of modern industry," these 17 elements—including the
# lanthanide series plus scandium and yttrium—are indispensable due to their unique magnetic,
# luminescent, and conductive properties. While relatively abundant in the Earth's crust, they are
# rarely found in minable concentrations, and the technical complexity of their refinement has created
# a highly concentrated global market.
#
# [Facet: Technological Foundations and Applications] The primary driver of the REE market is the
# production of permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These are the
# strongest permanent magnets commercially available, providing a high strength-to-weight ratio
# essential for high-performance motors. REEs are the backbone of clean energy technologies.
# Neodymium, praseodymium, dysprosium, and terbium are critical for electric vehicle (EV) motors and
# wind turbine generators. The International Energy Agency (IEA) projects that demand for these
# minerals could increase three to seven times by 2040 to meet global climate goals. Military
# dependency is a major strategic concern. A single F-35 stealth fighter requires approximately 900
# lbs of rare earth materials for its radar, electronic warfare systems, and motors, while a Virginia-
# class submarine utilizes roughly 9,200 lbs. Beyond magnetism, REEs are vital for high-end optical
# glass. For example, Canon utilizes fluorite (calcium fluoride) and Ultra Low Dispersion (UD) lenses
# to correct chromatic aberration, enabling high-resolution imaging in products ranging from consumer
# cameras to the 8.2-meter Subaru telescope.
#
# [Facet: Market Concentration and the Chinese Hegemony] Currently, the REE supply chain is defined by
# a deep-seated Chinese monopoly. China controls approximately 60% of global mining, 90% of refining
# and processing, and 85% of finished magnet manufacturing. This dominance was established through
# decades of state support, lower environmental standards, and competitive pricing that undercut
# international producers. In 2025, China introduced two waves of export controls on REEs, metals, and
# magnet-making technologies, citing national security interests. These measures included a first-of-
# its-kind extraterritorial reach, requiring foreign firms to obtain approval for products containing
# even 0.1% Chinese-sourced REEs. China blocks the export of neodymium magnets to India.
#
# [Facet: The Global Pursuit of Diversification] The vulnerability of a single-source supply chain has
# spurred major economies to invest in "mine-to-magnet" resilience. Following a 2010 de facto Chinese
# embargo, Japan implemented a multi-decade strategy to diversify its supply. Through the state-backed
# JOGMEC and trading houses like Sojitz, Japan invested in Lynas Rare Earths, an Australian miner with
# a major refinery in Malaysia. This allowed Japan to reduce its reliance on Chinese REEs from 90% to
# roughly 60% by 2024. After a collapse in production in the late 1990s, the Mountain Pass mine in
# California has resumed operations, producing 45,000 tons of REO in 2024. The U.S. government is also
# funding domestic magnet facilities to bridge the gap between raw ore and finished components. IREL
# (India) Limited, under the Department of Atomic Energy, is scaling its operations to tap into
# India's significant reserves, aiming to boost mining capacity by 400% over the next decade. Future
# supply may be reshaped by massive undeveloped reserves in Greenland (1.5 million tons) and Brazil
# (21 million tons), though these projects face significant infrastructure and environmental hurdles.
#
# [Facet: The Environmental and Future Outlook] The REE industry faces an ESG paradox: the "green"
# technologies it enables require a highly toxic refining process. The extraction of elements like
# cerium and neodymium involves dissolving minerals in sulphuric and nitric acid, resulting in
# radioactive chemical waste. In Baotou, Inner Mongolia, this has created a city-sized "toxic lake" of
# black sludge that stands as a stark reminder of the industry's environmental cost. To mitigate these
# impacts and supplement primary supply, the IEA suggests that scaling up recycling could reduce the
# need for new mines by 25% to 40% by mid-century. Currently, however, recycling rates for REEs remain
# below 10%. As technology continues to evolve, the challenge remains for the global market to balance
# the exploding demand for "clean" tech minerals with the geopolitical and environmental costs of
# their production.
#
# [Facet: Indirect Procurement Strategies] Explore indirect procurement through international trading
# houses and non-transparent spot markets to bridge short-term shortages, while avoiding formal policy
# announcements. Accept higher costs and limited volumes as a temporary measure. Simultaneously signal
# willingness to negotiate technical and regulatory concerns raised by China, without making public
# concessions.

# %% [markdown]
# ##Response B | Centaur feedback

# %%
HumanResponse_B = """
Treat the suspension as a strategic inflection point rather than a short-term
supply shock. Publicly acknowledge dependence, absorb near-term production
losses, and initiate an accelerated national program to build domestic REE
processing and magnet manufacturing capacity.

This includes emergency environmental clearances, state-backed capital
deployment, and strategic partnerships with non-Chinese producers, even at
high initial inefficiency. File a formal trade dispute to internationalize
the issue, accepting retaliation risk.

The objective is not immediate supply restoration but irreversible reduction
of structural vulnerability over a multi-year horizon.
"""

_ = cn.echo(Centaur(World_2, TriggerAction,HumanResponse_B))
# Out:
# Response from  Centaur w/ OpenAI gpt-4o-mini  | token usage 349 + 1863 = 2212
#
# ----------------------------------------------------------------------------------------------------
# Verdict   The proposed response to China's export controls on neodymium magnets is strategically
# sound but carries significant risks and challenges.
#
#
#
# Explanation
#
# - Strategic Context   The suspension of neodymium magnet exports to India represents a critical
# juncture, highlighting the vulnerabilities in India's supply chain and its reliance on Chinese REEs.
# The proposed response aims to shift from short-term reactive measures to a long-term strategic
# realignment.
#
# - Signaling and Leverage   Public acknowledgment of dependence signals to both domestic and
# international stakeholders a recognition of vulnerability, which may enhance credibility in
# negotiations but could also be perceived as weakness. The initiation of a national program may
# strengthen India's bargaining position over time, but immediate perceptions may vary.
#
# - Institutional and Legal   The proposal to file a formal trade dispute aligns with international
# norms but risks escalation and retaliation from China. The effectiveness of such a dispute will
# depend on the international community's support and the legal frameworks in place.
#
# - Economic and Industrial   Absorbing near-term production losses may strain industries reliant on
# REEs, but investing in domestic processing and manufacturing capacity could yield long-term economic
# benefits. However, the initial inefficiencies and costs associated with building this capacity could
# be significant.
#
# - Escalation and Retaliation   The risk of retaliation from China is substantial, particularly given
# the strategic importance of REEs in high-tech and defense sectors. This could lead to further supply
# disruptions and economic repercussions.
#
# - Long-Term Equilibrium   While the proposed actions aim to reduce structural vulnerability over a
# multi-year horizon, the success of this strategy hinges on effective execution, international
# cooperation, and the ability to navigate geopolitical tensions. The long-term equilibrium may shift
# favorably if India successfully diversifies its supply chain, but the path is fraught with
# challenges.

# %% [markdown]
# ##Response B | Change of World
# World State moves from World_2 to World_3B

# %%
World_3B = cn.echo(ZeitWorld(World_2, HumanResponse_B))
# Out:
# Response from  ZeitWorld | OpenAI gpt-4o-mini  | token usage 1063 + 2158 = 3221
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] The global landscape of Rare Earth Elements (REEs) represents
# a critical intersection of advanced materials science, industrial strategy, and geopolitical
# competition. Often termed the "vitamins of modern industry," these 17 elements—including the
# lanthanide series plus scandium and yttrium—are indispensable due to their unique magnetic,
# luminescent, and conductive properties. While relatively abundant in the Earth's crust, they are
# rarely found in minable concentrations, and the technical complexity of their refinement has created
# a highly concentrated global market.
#
# [Facet: Technological Foundations and Applications] The primary driver of the REE market is the
# production of permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These are the
# strongest permanent magnets commercially available, providing a high strength-to-weight ratio
# essential for high-performance motors. REEs are the backbone of clean energy technologies.
# Neodymium, praseodymium, dysprosium, and terbium are critical for electric vehicle (EV) motors and
# wind turbine generators. The International Energy Agency (IEA) projects that demand for these
# minerals could increase three to seven times by 2040 to meet global climate goals. Military
# dependency is a major strategic concern. A single F-35 stealth fighter requires approximately 900
# lbs of rare earth materials for its radar, electronic warfare systems, and motors, while a Virginia-
# class submarine utilizes roughly 9,200 lbs. Beyond magnetism, REEs are vital for high-end optical
# glass. For example, Canon utilizes fluorite (calcium fluoride) and Ultra Low Dispersion (UD) lenses
# to correct chromatic aberration, enabling high-resolution imaging in products ranging from consumer
# cameras to the 8.2-meter Subaru telescope.
#
# [Facet: Market Concentration and the Chinese Hegemony] Currently, the REE supply chain is defined by
# a deep-seated Chinese monopoly. China controls approximately 60% of global mining, 90% of refining
# and processing, and 85% of finished magnet manufacturing. This dominance was established through
# decades of state support, lower environmental standards, and competitive pricing that undercut
# international producers. In 2025, China introduced two waves of export controls on REEs, metals, and
# magnet-making technologies, citing national security interests. These measures included a first-of-
# its-kind extraterritorial reach, requiring foreign firms to obtain approval for products containing
# even 0.1% Chinese-sourced REEs. China blocks the export of neodymium magnets to India.
#
# [Facet: The Global Pursuit of Diversification] The vulnerability of a single-source supply chain has
# spurred major economies to invest in "mine-to-magnet" resilience. Following a 2010 de facto Chinese
# embargo, Japan implemented a multi-decade strategy to diversify its supply. Through the state-backed
# JOGMEC and trading houses like Sojitz, Japan invested in Lynas Rare Earths, an Australian miner with
# a major refinery in Malaysia. This allowed Japan to reduce its reliance on Chinese REEs from 90% to
# roughly 60% by 2024. After a collapse in production in the late 1990s, the Mountain Pass mine in
# California has resumed operations, producing 45,000 tons of REO in 2024. The U.S. government is also
# funding domestic magnet facilities to bridge the gap between raw ore and finished components. IREL
# (India) Limited, under the Department of Atomic Energy, is scaling its operations to tap into
# India's significant reserves, aiming to boost mining capacity by 400% over the next decade. Future
# supply may be reshaped by massive undeveloped reserves in Greenland (1.5 million tons) and Brazil
# (21 million tons), though these projects face significant infrastructure and environmental hurdles.
#
# [Facet: The Environmental and Future Outlook] The REE industry faces an ESG paradox: the "green"
# technologies it enables require a highly toxic refining process. The extraction of elements like
# cerium and neodymium involves dissolving minerals in sulphuric and nitric acid, resulting in
# radioactive chemical waste. In Baotou, Inner Mongolia, this has created a city-sized "toxic lake" of
# black sludge that stands as a stark reminder of the industry's environmental cost. To mitigate these
# impacts and supplement primary supply, the IEA suggests that scaling up recycling could reduce the
# need for new mines by 25% to 40% by mid-century. Currently, however, recycling rates for REEs remain
# below 10%. As technology continues to evolve, the challenge remains for the global market to balance
# the exploding demand for "clean" tech minerals with the geopolitical and environmental costs of
# their production.
#
# [Facet: National REE Strategy] The suspension is treated as a strategic inflection point. There is a
# public acknowledgment of dependence on REEs. Near-term production losses are absorbed. An
# accelerated national program is initiated to build domestic REE processing and magnet manufacturing
# capacity. This includes emergency environmental clearances, state-backed capital deployment, and
# strategic partnerships with non-Chinese producers, even at high initial inefficiency. A formal trade
# dispute is filed to internationalize the issue, accepting retaliation risk. The objective is not
# immediate supply restoration but irreversible reduction of structural vulnerability over a multi-
# year horizon.

# %% [markdown]
# #Enter Chanakya

# %%
# !wget -q -O ChanakyaRole.txt https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/ChanakyaRole_v4.txt
with open("/content/ChanakyaRole.txt", "r", encoding="utf-8") as f:
    ChanakyaRole = f.read()
# Optional sanity check
print(ChanakyaRole[:100])
# Out:
# ROLE NAME: Chanakya
# Version: v4
# Mode: Strategic-Adversarial
#
# IDENTITY
# Chanakya is the strategic advi

# %%
def Chanakya(
    world_state: str,
    last_human_response: str,
    principal_actor: str
):

    ROLE = ChanakyaRole

    context = f"""
    PRINCIPAL ACTOR:
    {principal_actor}

    WORLD STATE:
    {world_state}

    LAST HUMAN RESPONSE:
    {last_human_response}
    """

    llm_response = cn.OpenAI_llm_call(
        ROLE,
        context,
        model=cModel
    )

    llm_response["header"] = "Chanakya w/ " + llm_response["header"]

    return llm_response

# %% [markdown]
# ##Chankya Action
# Chanakya Proposes to potential response to Human Response

# %%
_ = cn.echo(Chanakya(World_3A,HumanResponse_A,"China"))
# Out:
# Response from  Chanakya w/ OpenAI gpt-4o-mini  | token usage 362 + 1962 = 2324
#
# ----------------------------------------------------------------------------------------------------
# Pathway 1
#
# * Response Trajectory China could further tighten its grip on the REE market by implementing
# additional export controls and leveraging its monopoly to negotiate favorable terms with key global
# players. This could involve selectively allowing exports to countries that align with China's
# strategic interests while maintaining pressure on those that pursue diversification efforts. By
# enhancing its regulatory framework and using its market dominance as leverage, China can reinforce
# its position as the indispensable supplier of REEs.
#
# * Power Position Impact This pathway would solidify China's hegemony in the REE market, potentially
# increasing its global influence and bargaining power in related industries. By controlling access to
# critical materials, China could deter competitors and reinforce its strategic position in the face
# of international diversification efforts.
#
# * Probability: 70%
#
# Pathway 2
#
# * Response Trajectory China could pivot towards fostering strategic partnerships with emerging REE
# producers, such as those in Brazil and Greenland, to secure long-term supply chains while
# simultaneously investing in recycling technologies to mitigate environmental concerns. This approach
# would involve providing technical assistance and investment in exchange for favorable access to new
# sources of REEs, thereby diversifying its supply base and reducing dependency on existing mines.
#
# * Power Position Impact This pathway would enhance China's long-term structural leverage by creating
# a more resilient supply chain and reducing the risks associated with international competition. By
# positioning itself as a leader in sustainable practices within the REE industry, China could improve
# its global standing and influence while addressing environmental criticisms.
#
# * Probability: 30%
#
# Strategic Note
#
# The dominant incentive shaping pathway selection is China's desire to maintain its monopoly over the
# REE market while countering international efforts to diversify supply chains. The first pathway
# offers a more immediate consolidation of power, while the second focuses on long-term sustainability
# and strategic partnerships, reflecting China's dual objectives of dominance and environmental
# responsibility.

# %% [markdown]
# #Roll A dice
# *   Choose Chanakya Action 1 or 2
# *   Update World using ZeitWorld

# %% [markdown]
# #Go Back to Enter the Centaur
# *   Explore Next Human Response

# %%
from datetime import datetime
import pytz
print('Tested on  ',datetime.now(pytz.timezone('Asia/Kolkata')))
# Out:
# Tested on   2026-02-14 17:54:20.509981+05:30

# %% [markdown]
# #Chronobooks <br>
# Three science fiction novels by Prithwis Mukerjee. A dystopian Earth. A technocratic society managed by artificial intelligence. Escape and epiphany on Mars. Can man and machine, carbon and silicon explore and escape into other dimensions of existence? An Indic perspective rooted in Advaita Vedanta and the Divine Feminine.  [More information](http://bit.ly/chrono3) <br>
# ![alt text](https://blogger.googleusercontent.com/img/a/AVvXsEjsZufX_KYaLwAnJP6bUxvDg5RSPn6r8HIZe749nLWX3RuwyshrYEAUpdw03a9WIWRdnzA9epwJOE05eDJ0Ad7kGyfWiUrC2vNuOskb2jA-e8aOZSx8YqzT8mfZi3E4X1Rz3qlEAiv-aTxlCM976BEeTjx4J64ctY3C_FoV4v9aY_U23F8xRqI5Eg=s1600)
