# %% [markdown]
# <a href="https://colab.research.google.com/github/prithwis/Centaur/blob/main/ManagementGuru_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/images/CentaurBanner2.png)<br>
#
#
# <hr>
#
# [Prithwis Mukerjee](http://www.linkedin.com/in/prithwis)<br>

# %% [markdown]
# #Management Guru
# A basic LLM based adjudicator for Case Based MBA Courses

# %% [markdown]
# #Install & Test Setup

# %% [markdown]
# Install + load key<br>
# OPENAI_API_KEY needs to defined as a Colab "secret" for the Google ID used to run this notebook

# %%
# !pip install --quiet openai

# !wget -q -O Centaur.py https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/utilities/Centaur_v1.py
import Centaur as centaur
# Out:
# API key loaded ✔
# Logged in as Calcutta prithwis@yantrajaal.com

# %% [markdown]
# Choose Model

# %%
#
# ---------------------------------------------------------------------------------------------------------
#| Model            | Best For                  | Notes                                       |
#| ---------------- | ------------------------- | ------------------------------------------- |
#| **GPT-4.1**      | Highest-quality reasoning | Ideal judge for complex scenario evaluation |
#| **GPT-4.1-mini** | Balanced reasoning & cost | Strong choice for adjudication logic        |
#| **GPT-4.1-nano** | High volume, low cost     | Good for simple reasoning tasks             |
#| **gpt-4o-mini**  | Prototyping & cheap       | Great starter, but upgrade recommended      |
# ---------------------------------------------------------------------------------------------------------
cModel = "gpt-4o-mini"
#cModel = "gpt-4.1-mini"

# %% [markdown]
# #Define Management Guru
# Specifies Role

# %%
# !wget -q -O Role.txt https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/mgmtGuru_v0.txt

with open("/content/Role.txt", "r", encoding="utf-8") as f:
    Role = f.read()
# Optional sanity check
print(Role[:100])
# Out:
# You are an adjudicator in a case-based management strategy exercise.
#
# Definition:
# - The task is to e

# %%
def MgmtGuruDecision(
    background_info: str,
    trigger_event: str,
    response: str
):

    ROLE = Role

    context = f"""
BACKGROND :
{background_info}

TRIGGER EVENT :
{trigger_event}

PROPOSD RESPONSE :
{response}

Evaluate the proposed response strictly under the stated adjudication principles.

Respond with:
1. Overall Assessment
2. Reasoning
"""

    llm_response = centaur.OpenAI_llm_call(ROLE, context,model=cModel)
    llm_response["header"] = "MgmtGuru w/ "+llm_response["header"]

    return(llm_response)

# %% [markdown]
# #Business Case
# Background + Trigger Event

# %%
Scenario = """
The market is a large, urbanising emerging economy with a young,
price-sensitive population and high smartphone penetration.

The sector is a digital platform business characterised by strong network
effects, multi-sided participation, and thin operating margins. Customer
switching costs are low, and demand is highly responsive to price incentives
and promotions.

The incumbent firm is a domestic market leader with approximately 45–50% market
share. It has built scale over several years through aggressive discounting,
a wide partner ecosystem, and familiarity with local regulatory and cultural
conditions. However, profitability remains elusive, and the firm depends on
periodic capital infusions to sustain incentives.

The industry operates in a regulatory grey zone. Government oversight exists
but is fragmented across jurisdictions, and policy direction is often reactive
rather than proactive. Public discourse increasingly focuses on data privacy,
labour conditions of gig workers, and market dominance by large platforms.

The incumbent’s internal capabilities include strong local operations,
moderate technology depth, and limited international experience. Its brand is
well recognised domestically but does not command strong pricing power.
"""

Crisis = """
A global platform company with deep financial reserves and advanced data and
AI capabilities announces its entry into the market within the next six months.

The entrant has publicly committed to gaining rapid scale, signalling
aggressive introductory pricing for customers and significantly higher
incentives for platform partners. Early estimates suggest effective prices
30–40% below prevailing market rates for an initial 12–18 month period.

The entrant has a history of prioritising growth over profitability in new
markets and has successfully displaced local incumbents in several comparable
geographies.

Following the announcement, the incumbent experiences immediate uncertainty
among partners, early signs of customer churn in pilot cities, and concern
from investors regarding its long-term viability. Internally, leadership is
divided between defending market share at all costs and reassessing the firm’s
strategic positioning.

The incumbent must decide how to respond before the entrant’s full-scale
launch, knowing that its next set of decisions will significantly shape its
competitive position, financial health, and regulatory relationships over
the next three to five years.
"""

# %% [markdown]
# #Evaluation of Responses
# Obtained by "calling" evaluater - currently MgmtGuruDecision()

# %% [markdown]
# ##Option 1

# %%
Response = """
The incumbent should respond aggressively by matching the entrant’s pricing
and increasing partner incentives to protect market share during the
initial entry phase. Given the importance of network effects in platform
markets, allowing a rival to scale rapidly could permanently weaken the
incumbent’s position.

The company already has significant local scale and operational knowledge,
which can be leveraged to execute promotions more efficiently than a new
entrant. Short-term losses should be accepted as a necessary investment to
preserve long-term dominance.

Simultaneously, the firm should intensify marketing efforts emphasising its
local roots, better understanding of customer needs, and existing partner
relationships. Regulatory engagement should also be strengthened to ensure
a level playing field, particularly around labour practices and data
localisation.

Once the entrant’s initial subsidy phase ends, the incumbent can gradually
rationalise incentives and return to a path of improved unit economics,
benefiting from its retained market leadership.
"""



_ = centaur.echo(MgmtGuruDecision(Scenario, Crisis, Response))
# Out:
# Response from  MgmtGuru w/ OpenAI gpt-4o-mini  | token usage 582 + 966 = 1548
#
# ----------------------------------------------------------------------------------------------------
# ### 1. Overall Assessment
#
# The proposed response demonstrates a coherent strategic logic aimed at defending market share in the
# face of a formidable new entrant. However, it carries significant risks, particularly regarding
# financial sustainability and long-term strategic positioning. While the emphasis on leveraging local
# capabilities and regulatory engagement is commendable, the aggressive pricing strategy may
# exacerbate existing profitability challenges and could lead to a price war that undermines the
# entire sector.
#
# ### 2. Reasoning
#
# **Strengths:** - **Alignment with Market Dynamics:** The response acknowledges the importance of
# network effects in platform markets, suggesting that rapid scaling by the entrant could jeopardize
# the incumbent’s competitive position. This recognition is crucial given the low switching costs and
# high price sensitivity of the customer base. - **Utilization of Local Strengths:** The incumbent's
# established local scale and operational knowledge are assets that can be leveraged to execute
# promotions more effectively than the new entrant, which may face challenges in adapting to local
# nuances. - **Marketing and Regulatory Engagement:** The proposal to intensify marketing efforts that
# highlight local roots and existing partner relationships is strategically sound. Strengthening
# regulatory engagement to advocate for a level playing field is also a prudent move, particularly in
# a fragmented regulatory environment.
#
# **Weaknesses:** - **Financial Viability Concerns:** The recommendation to match aggressive pricing
# and increase partner incentives could lead to unsustainable short-term losses. Given the incumbent's
# existing challenges with profitability and reliance on capital infusions, this approach raises
# concerns about financial health and investor confidence. - **Risk of Price War:** The strategy may
# inadvertently trigger a price war, which could further erode margins across the industry. This risk
# is particularly pronounced in a market characterized by thin operating margins and high price
# sensitivity. - **Lack of Long-Term Strategic Vision:** While the response focuses on immediate
# defensive actions, it lacks a clear long-term strategy beyond the initial subsidy phase of the
# entrant. The incumbent needs to consider how it will differentiate itself and sustain its market
# position once the competitive landscape stabilizes.
#
# **Key Risks:** - **Customer and Partner Reaction:** Aggressive pricing and increased incentives may
# not be sufficient to retain customers and partners if they perceive the new entrant as offering
# superior value or innovation. - **Regulatory Backlash:** Increased engagement with regulators could
# backfire if perceived as an attempt to stifle competition, particularly in a context where public
# discourse is focused on data privacy and labor conditions. - **Operational Strain:** The push for
# aggressive pricing and incentives may strain operational capabilities, particularly if the incumbent
# is already facing challenges in profitability and resource allocation.
#
# In summary, while the proposed response is grounded in a sound understanding of the competitive
# dynamics and leverages the incumbent's strengths, it is fraught with risks that could jeopardize
# both short-term stability and long-term strategic positioning. The incumbent must carefully weigh
# these factors and consider alternative strategies that balance immediate defensive actions with
# sustainable growth and profitability.

# %% [markdown]
# ##Option 2

# %%
Response = """
The incumbent should avoid a full-scale price war, as its financial reserves
are unlikely to sustain prolonged losses against a global competitor with
deeper capital. Instead, it should selectively defend high-density,
profitable urban clusters while allowing limited share erosion in highly
price-sensitive segments.

The firm should reposition itself away from pure price competition toward
reliability, service quality, and partner stability. This could include
guaranteed earnings for partners in core zones, differentiated service tiers
for customers, and investments in operational efficiency rather than
blanket subsidies.

In parallel, the incumbent should pursue strategic partnerships with local
players in payments, logistics, or mobility to strengthen ecosystem lock-in.
Proactive engagement with regulators and public communication around worker
welfare and data governance can further raise the entrant’s cost of
operating aggressively.

Over the medium term, this approach aims to preserve financial viability
and optionality, even if it results in a smaller but more sustainable
market position.
"""

_ = centaur.echo(MgmtGuruDecision(Scenario, Crisis, Response))
# Out:
# Response from  MgmtGuru w/ OpenAI gpt-4o-mini  | token usage 632 + 975 = 1607
#
# ----------------------------------------------------------------------------------------------------
# ### 1. Overall Assessment
#
# The proposed response demonstrates a coherent strategic logic that aligns with the incumbent's
# capabilities and the competitive dynamics of the market. It effectively recognizes the limitations
# of the incumbent's financial position relative to the new entrant and suggests a nuanced approach to
# defending market share without engaging in a destructive price war. However, the response also
# carries risks related to potential customer churn and the effectiveness of the proposed strategic
# partnerships.
#
# ### 2. Reasoning
#
# **Strengths:**
#
# - **Avoidance of Price War:** The recommendation to avoid a full-scale price war is prudent given
# the incumbent's financial constraints. Engaging in a price war against a well-capitalized competitor
# could lead to unsustainable losses and further erosion of profitability.    - **Selective Defense
# Strategy:** Focusing on high-density, profitable urban clusters allows the incumbent to concentrate
# resources where they can maintain a competitive advantage, potentially preserving margins in key
# areas.
#
# - **Repositioning Strategy:** Shifting the focus from price to reliability, service quality, and
# partner stability aligns well with the incumbent's existing strengths in local operations. This
# could help differentiate the brand in a market where price competition is fierce.
#
# - **Strategic Partnerships:** Pursuing partnerships with local players can enhance the ecosystem and
# create barriers to entry for the new competitor. This approach leverages the incumbent's local
# knowledge and relationships.
#
# - **Regulatory Engagement:** Proactive engagement with regulators and emphasis on worker welfare and
# data governance can help mitigate risks associated with regulatory scrutiny and enhance the firm's
# public image.
#
# **Weaknesses:**
#
# - **Risk of Customer Churn:** Allowing limited share erosion in highly price-sensitive segments may
# lead to significant customer churn, particularly if the new entrant's aggressive pricing attracts
# price-sensitive customers away from the incumbent.
#
# - **Dependence on Partnerships:** The success of the proposed partnerships with local players is
# uncertain and may require time to establish. If these partnerships do not materialize or fail to
# deliver expected benefits, the incumbent may struggle to maintain its competitive position.
#
# - **Operational Efficiency Investments:** While investments in operational efficiency are essential,
# the timeframe for realizing benefits from such investments may not align with the immediate threat
# posed by the new entrant. This could leave the incumbent vulnerable in the short term.
#
# **Key Risks:**
#
# - **Market Dynamics:** The proposed strategy assumes that the incumbent can effectively
# differentiate itself based on service quality and reliability. However, if the new entrant
# successfully captures market share through aggressive pricing and marketing, the incumbent may find
# it challenging to regain lost customers.
#
# - **Regulatory Landscape:** The fragmented regulatory environment poses a risk. While proactive
# engagement is beneficial, the effectiveness of such efforts in raising the entrant's operational
# costs is uncertain and may not yield immediate results.
#
# - **Long-Term Viability:** The strategy aims for a smaller but sustainable market position. However,
# this raises questions about the long-term viability of the business model, especially in a market
# characterized by low switching costs and high price sensitivity.
#
# In conclusion, while the proposed response is strategically sound and leverages the incumbent's
# strengths, it must carefully navigate the risks associated with customer retention, partnership
# effectiveness, and market dynamics to ensure long-term viability.

# %%
from datetime import datetime
import pytz
print('Tested on  ',datetime.now(pytz.timezone('Asia/Kolkata')))
# Out:
# Tested on   2026-02-13 14:26:39.512885+05:30

# %% [markdown]
# #Chronobooks <br>
# Three science fiction novels by Prithwis Mukerjee. A dystopian Earth. A technocratic society managed by artificial intelligence. Escape and epiphany on Mars. Can man and machine, carbon and silicon explore and escape into other dimensions of existence? An Indic perspective rooted in Advaita Vedanta and the Divine Feminine.  [More information](http://bit.ly/chrono3) <br>
# ![alt text](https://blogger.googleusercontent.com/img/a/AVvXsEjsZufX_KYaLwAnJP6bUxvDg5RSPn6r8HIZe749nLWX3RuwyshrYEAUpdw03a9WIWRdnzA9epwJOE05eDJ0Ad7kGyfWiUrC2vNuOskb2jA-e8aOZSx8YqzT8mfZi3E4X1Rz3qlEAiv-aTxlCM976BEeTjx4J64ctY3C_FoV4v9aY_U23F8xRqI5Eg=s1600)
