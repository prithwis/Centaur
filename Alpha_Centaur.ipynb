# %% [markdown]
# <a href="https://colab.research.google.com/github/prithwis/Centaur/blob/main/Alpha_Centaur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Yantrajaal Banner](https://github.com/Praxis-QR/RDWH/raw/main/images/YantraJaalBanner.png)<br>
#
#
# <hr>
#
# [Prithwis Mukerjee](http://www.linkedin.com/in/prithwis)<br>

# %% [markdown]
# #Centaur - Alpha
#
#
# The Centaur Project is a disciplined strategy sandbox where humans, AI, and a roll of the dice take turns shaping a shared world — without anyone being allowed to cheat by predicting the future. See [Centaur](https://github.com/prithwis/Centaur/tree/main/documents) on Github for more information

# %% [markdown]
# # Strategic Simulation Notebook
#
# This notebook implements a tri-layer geopolitical simulation engine composed of three distinct analytical agents:
#
# ### 1. ZeitWorld
# A neutral state recorder that maintains the evolving **World State** in a faceted, non-interpretive format.
# It updates structural reality strictly based on executed actions, without analysis or judgment.
#
# ### 2. Centaur
# A systemic evaluator that assesses proposed actions in terms of institutional coherence, escalation risk, economic burden, and equilibrium stability.
# Centaur judges strategic soundness within the broader international system.
#
# ### 3. Chanakya
# An agency-specific strategic engine that models adversarial response pathways.
# For a specified **Principal Actor**, it generates two probabilistic strategic reactions grounded in power calculus, leverage dynamics, and incentive alignment.
#
# ---
#
# Together, these components form the first operational version of the **Centaur Project** — a structured framework for simulating strategic interaction, adversarial dynamics, and disciplined world-state evolution without narrative drift or normative bias.

# %% [markdown]
# #Install PreRequisites and Utilities

# %% [markdown]
# Load API key<br>
# OPENAI_API_KEY needs to defined as a Colab "secret" for the Google ID used to run this notebook

# %%
# !pip install --quiet openai

#
#Most Python Code moved out to this file module
#
# !wget -q -O Centaur.py https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/utilities/Centaur_v2.py
import Centaur as cn
# Out:
# API key loaded ✔
# Logged in as Calcutta prithwis@yantrajaal.com

# %% [markdown]
# Select Model

# %%
# ---------------------------------------------------------------------------------------------------------
#| Model            | Best For                  | Notes                                       |
#| ---------------- | ------------------------- | ------------------------------------------- |
#| **GPT-4.1**      | Highest-quality reasoning | Ideal judge for complex scenario evaluation |
#| **GPT-4.1-mini** | Balanced reasoning & cost | Strong choice for adjudication logic        |
#| **GPT-4.1-nano** | High volume, low cost     | Good for simple reasoning tasks             |
#| **gpt-4o-mini**  | Prototyping & cheap       | Great starter, but upgrade recommended      |
# ---------------------------------------------------------------------------------------------------------
#cModel = "gpt-4o-mini"
cModel = "gpt-4.1-mini"
#cModel = "gpt-4.1"

# %% [markdown]
# #Define ZeitWorld
# ![alt text](https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/images/logo-S.png)<br>

# %%
#ZW_Role = cn.readRemote("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/ZeitWorldRole_v4.txt")
ZW_Role = cn.read_source("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/ZeitWorldRole_v4.txt")
#
#---------------------------------------------------------------------
#
def ZeitWorld(
    world_input: str,
    executed_action: str = None
):
    """
    ZeitWorld — World Synthesizer

    Inputs:
    - world_input:
        Either:
        (a) Raw unstructured narrative describing the world, OR
        (b) A semi-structured faceted world state from a previous turn

    - executed_action:
        A description of an action that has already been executed.
        May be None during world initialization.

    Output:
    - A semi-structured faceted world narrative suitable for subsequent steps.
    """

    ROLE = ZW_Role                  # As read from text file

    context = f"""
    WRAPPER DISCIPLINE:

    Operate strictly on the provided inputs.
    Produce only the updated faceted world state.
    Do not include explanation or meta commentary.
    Preserve structural format consistency.

    INVOCATION MODE:
    Task:

    - If this is initialization:
    - Extract salient facets from the world input.
    - Name each facet succinctly.Stabilize an initial interpretive world state.

    If this is an update:

    Reflect only the direct and second-order consequences of the executed action.
    Update relevant facets conservatively.
    Leave unrelated facets unchanged.

    INPUTS:

    WORLD INPUT:
    {world_input}

    EXECUTED ACTION:
    {executed_action if executed_action else "None (world initialization phase)"}
    """

    llm_response = cn.OpenAI_llm_call(
        ROLE,
        context,
        model=cModel
    )

    llm_response["header"] = "ZeitWorld | " + llm_response["header"]

    return llm_response
# Out:
# Character count: 4921
# ROLE NAME: ZEITWORLD
# Version: v4
# Mode: STRICT-LEDGER
#
# IDENTITY
# Zeitworld is the World State Ledger o

# %% [markdown]
# #Initialise World

# %%
#World_0 = cn.readRemote("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/worlds/REEWorld_01.txt")
#World_0 = cn.read_source("REEWorld_01.txt")
World_0 = cn.read_source("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/worlds/REEWorld_01.txt")

#centaur.reveal(KalDarpanWorldUpdate(World_0))
World_1 = cn.echo(ZeitWorld(World_0))
# Out:
# Character count: 4820
# The global landscape of Rare Earth Elements (REEs) represents a critical intersection of advanced ma
# Response from  ZeitWorld | OpenAI gpt-4.1  | token usage 602 + 2087 = 2689
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] Rare Earth Elements (REEs) are a group of 17 elements,
# including the lanthanide series plus scandium and yttrium. They are indispensable due to their
# unique magnetic, luminescent, and conductive properties. Although relatively abundant in the Earth's
# crust, they are rarely found in minable concentrations, and the technical complexity of their
# refinement has created a highly concentrated global market.
#
# [Facet: Technological Applications] The primary driver of the REE market is the production of
# permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These magnets are essential for
# high-performance motors due to their high strength-to-weight ratio. REEs are critical for clean
# energy technologies, including electric vehicle motors and wind turbine generators. The
# International Energy Agency projects that demand for these minerals could increase three to seven
# times by 2040 to meet global climate goals. Military systems, such as the F-35 stealth fighter and
# Virginia-class submarine, require large quantities of REEs for radar, electronic warfare systems,
# and motors. REEs are also vital for high-end optical glass, with applications in consumer cameras
# and large telescopes.
#
# [Facet: Market Concentration and Chinese Role] China controls approximately 60% of global REE
# mining, 90% of refining and processing, and 85% of finished magnet manufacturing. This dominance was
# established through decades of state support, lower environmental standards, and competitive
# pricing. In 2025, China introduced two waves of export controls on REEs, metals, and magnet-making
# technologies, citing national security interests. These measures included extraterritorial
# requirements for foreign firms to obtain approval for products containing even 0.1% Chinese-sourced
# REEs.
#
# [Facet: Diversification Efforts] Japan implemented a multi-decade strategy to diversify its REE
# supply after a 2010 Chinese embargo, reducing reliance on Chinese REEs from 90% to roughly 60% by
# 2024 through investments in Lynas Rare Earths. The United States resumed operations at the Mountain
# Pass mine in California, producing 45,000 tons of REO in 2024, and is funding domestic magnet
# facilities. India, through IREL (India) Limited, is scaling operations to boost mining capacity by
# 400% over the next decade. Greenland and Brazil have large undeveloped REE reserves, though these
# face infrastructure and environmental challenges.
#
# [Facet: Environmental Impact and Recycling] The REE industry involves highly toxic refining
# processes, including the use of sulphuric and nitric acid, resulting in radioactive chemical waste.
# In Baotou, Inner Mongolia, this has created a large "toxic lake" of black sludge. Recycling could
# reduce the need for new mines by 25% to 40% by mid-century, but current recycling rates for REEs
# remain below 10%. The industry faces the challenge of balancing demand for clean technology minerals
# with the environmental costs of production.

# %% [markdown]
# #Update World State after Initial ("Trigger") Action
# State of World moves from World_1 to World_2

# %%
TriggerAction = """
China blocks the export of neodymium magnets to India by delaying export licenses indefinitely
"""

World_2 = cn.echo(ZeitWorld(World_1, TriggerAction))
# Out:
# Response from  ZeitWorld | OpenAI gpt-4.1  | token usage 619 + 1742 = 2361
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] Rare Earth Elements (REEs) are a group of 17 elements,
# including the lanthanide series plus scandium and yttrium. They are indispensable due to their
# unique magnetic, luminescent, and conductive properties. Although relatively abundant in the Earth's
# crust, they are rarely found in minable concentrations, and the technical complexity of their
# refinement has created a highly concentrated global market.
#
# [Facet: Technological Applications] The primary driver of the REE market is the production of
# permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These magnets are essential for
# high-performance motors due to their high strength-to-weight ratio. REEs are critical for clean
# energy technologies, including electric vehicle motors and wind turbine generators. The
# International Energy Agency projects that demand for these minerals could increase three to seven
# times by 2040 to meet global climate goals. Military systems, such as the F-35 stealth fighter and
# Virginia-class submarine, require large quantities of REEs for radar, electronic warfare systems,
# and motors. REEs are also vital for high-end optical glass, with applications in consumer cameras
# and large telescopes.
#
# [Facet: Market Concentration and Chinese Role] China controls approximately 60% of global REE
# mining, 90% of refining and processing, and 85% of finished magnet manufacturing. This dominance was
# established through decades of state support, lower environmental standards, and competitive
# pricing. In 2025, China introduced two waves of export controls on REEs, metals, and magnet-making
# technologies, citing national security interests. These measures included extraterritorial
# requirements for foreign firms to obtain approval for products containing even 0.1% Chinese-sourced
# REEs. China blocks the export of neodymium magnets to India by delaying export licenses
# indefinitely.
#
# [Facet: Diversification Efforts] Japan implemented a multi-decade strategy to diversify its REE
# supply after a 2010 Chinese embargo, reducing reliance on Chinese REEs from 90% to roughly 60% by
# 2024 through investments in Lynas Rare Earths. The United States resumed operations at the Mountain
# Pass mine in California, producing 45,000 tons of REO in 2024, and is funding domestic magnet
# facilities. India, through IREL (India) Limited, is scaling operations to boost mining capacity by
# 400% over the next decade. Greenland and Brazil have large undeveloped REE reserves, though these
# face infrastructure and environmental challenges.
#
# [Facet: Environmental Impact and Recycling] The REE industry involves highly toxic refining
# processes, including the use of sulphuric and nitric acid, resulting in radioactive chemical waste.
# In Baotou, Inner Mongolia, this has created a large "toxic lake" of black sludge. Recycling could
# reduce the need for new mines by 25% to 40% by mid-century, but current recycling rates for REEs
# remain below 10%. The industry faces the challenge of balancing demand for clean technology minerals
# with the environmental costs of production.

# %% [markdown]
# #Enter the Centaur
# ![alt text](https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/images/logo-S.png)<br>

# %%
#Centaur_Role =  cn.readRemote("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/CentaurRole_v2.txt")
Centaur_Role =  cn.read_source("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/CentaurRole_v2.txt")
#
#---------------------------------------------------------------------
#
def Centaur(
    world_state: str,
    trigger_action: str,
    suggested_response: str
):

    ROLE = Centaur_Role

    # ---------------------------------------------------------------------------------------------------------

    context = f"""
    WORLD STATE:
    {world_state}

    TRIGGER ACTION:
    {trigger_action}

    SUGGESTED HUMAN RESPONSE:
    {suggested_response}

    Provide adjudication according to the stated ROLE.
    """

    llm_response = cn.OpenAI_llm_call(ROLE, context, model=cModel)
    llm_response["header"] = "Centaur w/ " + llm_response["header"]

    return llm_response
# Out:
# Character count: 3418
# ROLE NAME: Centaur
# Version: v2
# Mode: Adjudicative
#
# IDENTITY
# Centaur is the system-level adjudicator

# %% [markdown]
# #A, B - Two alternative Human Actions
# that will be evaluated by Centaur

# %% [markdown]
# ## A | Centaur Feedback

# %%
HumanResponse_A = """
Explore indirect procurement through international trading houses and
non-transparent spot markets to bridge short-term shortages, while avoiding
formal policy announcements. Accept higher costs and limited volumes as a
temporary measure.

Simultaneously signal willingness to negotiate technical and regulatory
concerns raised by China, without making public concessions.
"""

_ = cn.echo(Centaur(World_2, TriggerAction,HumanResponse_A))
# Out:
# Response from  Centaur w/ OpenAI gpt-4.1  | token usage 297 + 1390 = 1687
#
# ----------------------------------------------------------------------------------------------------
# Verdict This response is proportionate and preserves strategic ambiguity, offering tactical relief
# without materially altering long-term leverage or institutional exposure.
#
# Explanation
#
# - Strategic Context   India faces acute vulnerability due to concentrated Chinese control over
# neodymium magnet supply, with domestic alternatives years away and immediate needs in defense and
# clean energy sectors; indirect procurement is a pragmatic stopgap that avoids escalation or overt
# dependency.
#
# - Signaling and Leverage   By using opaque channels and refraining from public statements, India
# avoids direct confrontation, preserves bargaining flexibility, and signals both resilience and
# openness to dialogue, though it does not fundamentally shift the underlying power asymmetry.
#
# - Institutional and Legal   This approach skirts formal trade rules without overt violation,
# minimizing exposure to WTO or bilateral dispute mechanisms, and avoids triggering automatic
# countermeasures or legal escalation from China or third parties.
#
# - Economic and Industrial   Short-term costs will rise and supply will be constrained, but this
# avoids immediate industrial disruption; however, reliance on non-transparent markets may introduce
# quality and reliability risks, and does not incentivize rapid domestic capacity-building.
#
# - Escalation and Retaliation   The absence of formal policy moves or public accusations reduces the
# risk of further Chinese retaliation or broader market destabilization, maintaining a low profile in
# a sensitive domain.
#
# - Long-Term Equilibrium   This action is tactical, not structural; it buys time but does not address
# the underlying strategic vulnerability, and unless paired with sustained diversification or domestic
# investment, India’s long-term bargaining position remains constrained.

# %% [markdown]
# ## A | Change of World State
# State of World moves from World_2 to World_3A

# %%
World_3A = cn.echo(ZeitWorld(World_2, HumanResponse_A))
# Out:
# Response from  ZeitWorld | OpenAI gpt-4.1  | token usage 670 + 1802 = 2472
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] Rare Earth Elements (REEs) are a group of 17 elements,
# including the lanthanide series plus scandium and yttrium. They are indispensable due to their
# unique magnetic, luminescent, and conductive properties. Although relatively abundant in the Earth's
# crust, they are rarely found in minable concentrations, and the technical complexity of their
# refinement has created a highly concentrated global market.
#
# [Facet: Technological Applications] The primary driver of the REE market is the production of
# permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These magnets are essential for
# high-performance motors due to their high strength-to-weight ratio. REEs are critical for clean
# energy technologies, including electric vehicle motors and wind turbine generators. The
# International Energy Agency projects that demand for these minerals could increase three to seven
# times by 2040 to meet global climate goals. Military systems, such as the F-35 stealth fighter and
# Virginia-class submarine, require large quantities of REEs for radar, electronic warfare systems,
# and motors. REEs are also vital for high-end optical glass, with applications in consumer cameras
# and large telescopes.
#
# [Facet: Market Concentration and Chinese Role] China controls approximately 60% of global REE
# mining, 90% of refining and processing, and 85% of finished magnet manufacturing. This dominance was
# established through decades of state support, lower environmental standards, and competitive
# pricing. In 2025, China introduced two waves of export controls on REEs, metals, and magnet-making
# technologies, citing national security interests. These measures included extraterritorial
# requirements for foreign firms to obtain approval for products containing even 0.1% Chinese-sourced
# REEs. China blocks the export of neodymium magnets to India by delaying export licenses
# indefinitely.
#
# [Facet: Diversification Efforts] Japan implemented a multi-decade strategy to diversify its REE
# supply after a 2010 Chinese embargo, reducing reliance on Chinese REEs from 90% to roughly 60% by
# 2024 through investments in Lynas Rare Earths. The United States resumed operations at the Mountain
# Pass mine in California, producing 45,000 tons of REO in 2024, and is funding domestic magnet
# facilities. India, through IREL (India) Limited, is scaling operations to boost mining capacity by
# 400% over the next decade. Greenland and Brazil have large undeveloped REE reserves, though these
# face infrastructure and environmental challenges. Some actors explore indirect procurement through
# international trading houses and non-transparent spot markets to bridge short-term shortages,
# accepting higher costs and limited volumes as a temporary measure. Some actors simultaneously signal
# willingness to negotiate technical and regulatory concerns raised by China, without making public
# concessions.
#
# [Facet: Environmental Impact and Recycling] The REE industry involves highly toxic refining
# processes, including the use of sulphuric and nitric acid, resulting in radioactive chemical waste.
# In Baotou, Inner Mongolia, this has created a large "toxic lake" of black sludge. Recycling could
# reduce the need for new mines by 25% to 40% by mid-century, but current recycling rates for REEs
# remain below 10%. The industry faces the challenge of balancing demand for clean technology minerals
# with the environmental costs of production.

# %% [markdown]
# ## B | Centaur feedback

# %%
HumanResponse_B = """
Treat the suspension as a strategic inflection point rather than a short-term
supply shock. Publicly acknowledge dependence, absorb near-term production
losses, and initiate an accelerated national program to build domestic REE
processing and magnet manufacturing capacity.

This includes emergency environmental clearances, state-backed capital
deployment, and strategic partnerships with non-Chinese producers, even at
high initial inefficiency. File a formal trade dispute to internationalize
the issue, accepting retaliation risk.

The objective is not immediate supply restoration but irreversible reduction
of structural vulnerability over a multi-year horizon.
"""

_ = cn.echo(Centaur(World_2, TriggerAction,HumanResponse_B))
# Out:
# Response from  Centaur w/ OpenAI gpt-4.1  | token usage 354 + 1446 = 1800
#
# ----------------------------------------------------------------------------------------------------
# Verdict The proposed response is strategically proportional, prioritizing long-term structural
# repositioning over short-term relief, but entails significant economic, environmental, and
# diplomatic exposure with uncertain near-term mitigation.
#
# Explanation
#
# - Strategic Context The action reframes the supply disruption as a catalyst for systemic change,
# signaling intent to reduce dependency on Chinese REEs and magnets, which aligns with broader global
# diversification trends but requires sustained political and financial commitment.
#
# - Signaling and Leverage Public acknowledgment of vulnerability, paired with a visible acceleration
# of domestic capacity-building, signals resolve and may deter further coercion, but also exposes
# current weakness and could invite additional pressure during the transition period;
# internationalizing the dispute seeks to rally external support and shift bargaining leverage over
# time.
#
# - Institutional and Legal Emergency environmental clearances and state-backed investment challenge
# existing regulatory norms, risking domestic and international criticism for environmental trade-
# offs; filing a trade dispute leverages institutional mechanisms but may have limited immediate
# effect given the complexity of REE supply chains and enforcement limitations.
#
# - Economic and Industrial Absorbing near-term losses and investing in inefficient domestic capacity
# will impose substantial costs, with uncertain timelines for achieving competitive scale;
# partnerships with non-Chinese producers may accelerate diversification but cannot fully offset
# Chinese dominance in the short term.
#
# - Escalation and Retaliation Accepting retaliation risk is explicit, and China may respond with
# further restrictions or indirect economic measures; however, the measured, multi-pronged approach
# avoids direct confrontation and frames the response as defensive rather than escalatory.
#
# - Long-Term Equilibrium If sustained, the strategy could meaningfully reduce structural
# vulnerability and contribute to a more multipolar REE supply chain, but success depends on political
# durability, environmental management, and the ability to absorb interim costs without destabilizing
# key industries.

# %% [markdown]
# ## B | Change of World
# World State moves from World_2 to World_3B

# %%
World_3B = cn.echo(ZeitWorld(World_2, HumanResponse_B))
# Out:
# Response from  ZeitWorld | OpenAI gpt-4.1  | token usage 708 + 1858 = 2566
#
# ----------------------------------------------------------------------------------------------------
# WORLD STATE (Faceted Narrative)
#
# [Facet: Rare Earth Elements Overview] Rare Earth Elements (REEs) are a group of 17 elements,
# including the lanthanide series plus scandium and yttrium. They are indispensable due to their
# unique magnetic, luminescent, and conductive properties. Although relatively abundant in the Earth's
# crust, they are rarely found in minable concentrations, and the technical complexity of their
# refinement has created a highly concentrated global market.
#
# [Facet: Technological Applications] The primary driver of the REE market is the production of
# permanent magnets, specifically Neodymium-Iron-Boron (NdFeB) alloys. These magnets are essential for
# high-performance motors due to their high strength-to-weight ratio. REEs are critical for clean
# energy technologies, including electric vehicle motors and wind turbine generators. The
# International Energy Agency projects that demand for these minerals could increase three to seven
# times by 2040 to meet global climate goals. Military systems, such as the F-35 stealth fighter and
# Virginia-class submarine, require large quantities of REEs for radar, electronic warfare systems,
# and motors. REEs are also vital for high-end optical glass, with applications in consumer cameras
# and large telescopes.
#
# [Facet: Market Concentration and Chinese Role] China controls approximately 60% of global REE
# mining, 90% of refining and processing, and 85% of finished magnet manufacturing. This dominance was
# established through decades of state support, lower environmental standards, and competitive
# pricing. In 2025, China introduced two waves of export controls on REEs, metals, and magnet-making
# technologies, citing national security interests. These measures included extraterritorial
# requirements for foreign firms to obtain approval for products containing even 0.1% Chinese-sourced
# REEs. China blocks the export of neodymium magnets to India by delaying export licenses
# indefinitely. A formal trade dispute has been filed to internationalize the issue, with acceptance
# of retaliation risk.
#
# [Facet: Diversification Efforts] Japan implemented a multi-decade strategy to diversify its REE
# supply after a 2010 Chinese embargo, reducing reliance on Chinese REEs from 90% to roughly 60% by
# 2024 through investments in Lynas Rare Earths. The United States resumed operations at the Mountain
# Pass mine in California, producing 45,000 tons of REO in 2024, and is funding domestic magnet
# facilities. India, through IREL (India) Limited, is scaling operations to boost mining capacity by
# 400% over the next decade. Greenland and Brazil have large undeveloped REE reserves, though these
# face infrastructure and environmental challenges. An accelerated national program has been initiated
# to build domestic REE processing and magnet manufacturing capacity, including emergency
# environmental clearances, state-backed capital deployment, and strategic partnerships with non-
# Chinese producers, even at high initial inefficiency.
#
# [Facet: Environmental Impact and Recycling] The REE industry involves highly toxic refining
# processes, including the use of sulphuric and nitric acid, resulting in radioactive chemical waste.
# In Baotou, Inner Mongolia, this has created a large "toxic lake" of black sludge. Recycling could
# reduce the need for new mines by 25% to 40% by mid-century, but current recycling rates for REEs
# remain below 10%. The industry faces the challenge of balancing demand for clean technology minerals
# with the environmental costs of production. Emergency environmental clearances have been granted as
# part of the accelerated national program to build domestic REE processing and magnet manufacturing
# capacity.

# %% [markdown]
# #Chanakya - THe Last Word
# ![alt text](https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/images/logo-S.png)<br>

# %%
#ChanakyaRole = cn.readRemote("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/ChanakyaRole_v4.txt")
ChanakyaRole = cn.read_source("https://raw.githubusercontent.com/prithwis/Centaur/refs/heads/main/roles/ChanakyaRole_v4.txt")
#
#
#---------------------------------------------------------------------
#
def Chanakya(
    world_state: str,
    last_human_response: str,
    principal_actor: str
):

    ROLE = ChanakyaRole

    context = f"""
    PRINCIPAL ACTOR:
    {principal_actor}

    WORLD STATE:
    {world_state}

    LAST HUMAN RESPONSE:
    {last_human_response}
    """

    llm_response = cn.OpenAI_llm_call(
        ROLE,
        context,
        model=cModel
    )

    llm_response["header"] = "Chanakya w/ " + llm_response["header"]

    return llm_response
# Out:
# Character count: 4429
# ROLE NAME: Chanakya
# Version: v4
# Mode: Strategic-Adversarial
#
# IDENTITY
# Chanakya is the strategic advi

# %% [markdown]
# ##Chankya Action
# Chanakya Proposes to potential response to Human Response

# %%
_ = cn.echo(Chanakya(World_3A,HumanResponse_A,"China"))
# Out:
# Response from  Chanakya w/ OpenAI gpt-4.1  | token usage 382 + 1623 = 2005
#
# ----------------------------------------------------------------------------------------------------
# Pathway 1
#
# - Response Trajectory   Intensify enforcement of extraterritorial export controls by auditing and
# sanctioning international trading houses and downstream manufacturers found to be circumventing
# Chinese REE restrictions, leveraging China’s dominant position in refining and magnet manufacturing.
# Publicize high-profile enforcement actions to deter indirect procurement and signal the risks of
# non-compliance, while selectively offering regulatory relief to actors who demonstrate alignment
# with Chinese technical standards or strategic interests.
#
# - Power Position Impact   This pathway reinforces China’s structural leverage by tightening control
# over global REE flows, raising compliance costs for diversification efforts, and compelling foreign
# actors to engage on Chinese terms. It deters circumvention, preserves pricing power, and increases
# the bargaining value of regulatory relief, but risks accelerating long-term diversification
# incentives.
#
# - Probability: 70%
#
# Pathway 2
#
# - Response Trajectory   Initiate a targeted relaxation of export controls for select foreign firms
# or countries that offer reciprocal market access or technology transfer in sectors of strategic
# value to China, using case-by-case waivers as bargaining chips. Maintain overall restrictions but
# create a formalized, opaque process for exemptions, incentivizing foreign actors to compete for
# Chinese favor and fragmenting coalition efforts to diversify away from Chinese REEs.
#
# - Power Position Impact   This pathway exploits China’s gatekeeper role to extract concessions and
# deepen bilateral dependencies, slowing collective diversification by dividing foreign actors. It
# preserves leverage while reducing immediate incentives for circumvention, but may marginally weaken
# the deterrent effect of blanket controls if exemptions become too accessible.
#
# - Probability: 30%
#
# Strategic Note
#
# The dominant incentive is to maximize the durability of China’s REE leverage by deterring
# circumvention and compelling foreign compliance, especially as diversification efforts gather
# momentum. Pathway 1 is favored due to its direct enforcement mechanism and signaling value, while
# Pathway 2 is constrained by the risk of undermining the perceived rigidity of Chinese controls.

# %% [markdown]
# #Roll A dice
# *   Choose Chanakya Action 1 or 2
# *   Update World using ZeitWorld

# %%
import random

n = random.randint(0, 1000)
print(n)
# Out:
# 707

# %% [markdown]
# #Go Back to Enter the Centaur
# *   Explore Next Human Response

# %%
from datetime import datetime
import pytz
print('Tested on  ',datetime.now(pytz.timezone('Asia/Kolkata')))
# Out:
# Tested on   2026-02-21 20:47:20.743860+05:30

# %% [markdown]
# #Chronobooks <br>
# Three science fiction novels by Prithwis Mukerjee. A dystopian Earth. A technocratic society managed by artificial intelligence. Escape and epiphany on Mars. Can man and machine, carbon and silicon explore and escape into other dimensions of existence? An Indic perspective rooted in Advaita Vedanta and the Divine Feminine.  [More information](http://bit.ly/chrono3) <br>
# ![alt text](https://blogger.googleusercontent.com/img/a/AVvXsEjsZufX_KYaLwAnJP6bUxvDg5RSPn6r8HIZe749nLWX3RuwyshrYEAUpdw03a9WIWRdnzA9epwJOE05eDJ0Ad7kGyfWiUrC2vNuOskb2jA-e8aOZSx8YqzT8mfZi3E4X1Rz3qlEAiv-aTxlCM976BEeTjx4J64ctY3C_FoV4v9aY_U23F8xRqI5Eg=s1600)
